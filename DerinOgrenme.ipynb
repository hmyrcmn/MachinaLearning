# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/MachinaLearning/blob/main/DerinOgrenme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -–upgrade –no-deps git+git://github.com/Theano/Theano.git
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -–

# %%
# !pip install -–upgrade keras
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -–

# %%
# !pip3 install -–upgrade
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -–

# %%
import pandas as pd
data=pd.read_csv('/content/Churn_Modelling.csv')
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
data.head()
#verinin ilk 5 değeri
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
data.shape
#verinin boyutunun öğrenilmesi
# metadata (veriye ait veri )
# Out:
# (10000, 14)

# %%
#veride null degerler varmı nasıl kodntrol edili
cauntNull=data.isnull().sum()
print(cauntNull)
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
x=data.iloc[:,3:13]
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
x=data.iloc[:,3:13].values # verilerdeki ilk 3 öznitelik (RowNumber	CustomerId	Surname) ayırt edildi model başarısını olumsuz etkilememesi için : burada sensörlerin ıd gibi degerler olursa projede onlar drop edilmeli
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
y=data.iloc[:,13:].values#y bagımlı değişken .
y
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
from sklearn import preprocessing

le =preprocessing.LabelEncoder()

x[:,1]=le.fit_transform(x[:,1]) #kategorik değişken olan georapy sayısal bir değere dönüştürüldü
x
# Out:
# array([[619, 0, 'Female', ..., 1, 1, 101348.88],
#        [608, 2, 'Female', ..., 0, 1, 112542.58],
#        [502, 0, 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 'Female', ..., 0, 1, 42085.58],
#        [772, 1, 'Male', ..., 1, 0, 92888.52],
#        [792, 0, 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
le2 =preprocessing.LabelEncoder()

x[:,2]=le2.fit_transform(x[:,2]) #kategorik değişken olan cinsiyet  sayısal bir değere dönüştürüldü kadın 0 erkek 1 olarak düzenlendi
x
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# one hot encoding ile 0 1 2 degerlerine dönüştürülen kategorik değişken 0 -1 ile temsil edilir .
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

ohe=ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(sparse=False, dtype=float), [1])],
    remainder='passthrough'
)

x=ohe.fit_transform(x)
x[:,1]

x
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# kategorik verileri  ülke tr fr us ın işlenebilecek formata dönüştüürlülmesi

# %%
#eğitim ve test verilerinin oluştrulması
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)

x_train
# Out:
# array([[1.0, 0.0, 0.0, ..., 0, 0, 163112.9],
#        [1.0, 0.0, 0.0, ..., 1, 1, 74275.08],
#        [1.0, 0.0, 0.0, ..., 0, 1, 62810.91],
#        ...,
#        [1.0, 0.0, 0.0, ..., 1, 0, 181429.87],
#        [0.0, 0.0, 1.0, ..., 1, 1, 148750.16],
#        [0.0, 1.0, 0.0, ..., 1, 0, 118855.26]], dtype=object)

# %%
x_test
# Out:
# array([[0.0, 1.0, 0.0, ..., 1, 1, 192852.67],
#        [1.0, 0.0, 0.0, ..., 1, 0, 128702.1],
#        [0.0, 0.0, 1.0, ..., 1, 1, 75732.25],
#        ...,
#        [0.0, 0.0, 1.0, ..., 0, 0, 120284.67],
#        [0.0, 1.0, 0.0, ..., 0, 0, 125140.72],
#        [1.0, 0.0, 0.0, ..., 0, 1, 192131.77]], dtype=object)

# %%
y_train
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
y_test
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [0],
#        [1],
#        [0]])

# %% [markdown]
# ÖZNİTEKİL ÖLÇEKLEME

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

X_train=sc.fit_transform(x_train)
X_test=sc.fit_transform(x_test)

# %% [markdown]
# yapay sinir ağı oluşturma

# %%
import keras

#yağay sinir ağı oluştur komutu veriliyor keras a
from keras.models import Sequential

#katman oluştruma
from keras.layers import Dense

classifier=Sequential() # yapay sinir ağı oluşturuldu içi boş
# 6 nöron ve 11 nöron girişinden oluşan katman eklendi
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=12))
  # kaç tane gizli katman veirleceği :32   11+1/2 = 6  ,nput +output

# 2 gizli katman
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))


# çıkış katmanı
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))


#optimizasyon :
#binary kullanılacak bagımsız değişken 0 1 den oluşuyor
classifier.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

#adam sdg :veri kümesini küçük parçalara (minibatch) bölmek ve her minibatch için gradyan hesaplamalarını yapmaktır.

# %%
# noron network çalıştırma
classifier.fit(X_train, y_train, epochs=50)
# kaç aşamada tekrar edileceğini eposchi belirler

y_pred=classifier.predict(X_test)
y_pred
# Out:
# Epoch 1/50
# 210/210 [==============================] - 2s 3ms/step - loss: 0.5952 - accuracy: 0.7967
# Epoch 2/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.4373 - accuracy: 0.7979
# Epoch 3/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4230 - accuracy: 0.7979
# Epoch 4/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4175 - accuracy: 0.7979
# Epoch 5/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4136 - accuracy: 0.7979
# Epoch 6/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4100 - accuracy: 0.7979
# Epoch 7/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4066 - accuracy: 0.7979
# Epoch 8/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.4033 - accuracy: 0.7979
# Epoch 9/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4000 - accuracy: 0.8106
# Epoch 10/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3968 - accuracy: 0.8245
# Epoch 11/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3939 - accuracy: 0.8254
# Epoch 12/50
# 210/210 [==============================] - 1s 6ms/step - loss: 0.3911 - accuracy: 0.8272
# Epoch 13/50
# 210/210 [==============================] - 1s 6ms/step - loss: 0.3885 - accuracy: 0.8263
# Epoch 14/50
# 210/210 [==============================] - 1s 6ms/step - loss: 0.3856 - accuracy: 0.8260
# Epoch 15/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3825 - accuracy: 0.8267
# Epoch 16/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3796 - accuracy: 0.8279
# Epoch 17/50
# 210/210 [==============================] - 1s 6ms/step - loss: 0.3771 - accuracy: 0.8370
# Epoch 18/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3745 - accuracy: 0.8436
# Epoch 19/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3723 - accuracy: 0.8437
# Epoch 20/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3698 - accuracy: 0.8454
# Epoch 21/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3680 - accuracy: 0.8467
# Epoch 22/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3669 - accuracy: 0.8488
# Epoch 23/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3651 - accuracy: 0.8493
# Epoch 24/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3638 - accuracy: 0.8507
# Epoch 25/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3622 - accuracy: 0.8519
# Epoch 26/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3611 - accuracy: 0.8540
# Epoch 27/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3606 - accuracy: 0.8549
# Epoch 28/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3592 - accuracy: 0.8513
# Epoch 29/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3584 - accuracy: 0.8539
# Epoch 30/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3579 - accuracy: 0.8549
# Epoch 31/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3579 - accuracy: 0.8546
# Epoch 32/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3573 - accuracy: 0.8569
# Epoch 33/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3566 - accuracy: 0.8543
# Epoch 34/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3561 - accuracy: 0.8552
# Epoch 35/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3554 - accuracy: 0.8548
# Epoch 36/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3551 - accuracy: 0.8575
# Epoch 37/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3554 - accuracy: 0.8539
# Epoch 38/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3541 - accuracy: 0.8569
# Epoch 39/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3540 - accuracy: 0.8584
# Epoch 40/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3535 - accuracy: 0.8564
# Epoch 41/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3535 - accuracy: 0.8564
# Epoch 42/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3531 - accuracy: 0.8584
# Epoch 43/50
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3531 - accuracy: 0.8585
# Epoch 44/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3529 - accuracy: 0.8582
# Epoch 45/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3524 - accuracy: 0.8591
# Epoch 46/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3519 - accuracy: 0.8588
# Epoch 47/50
# 210/210 [==============================] - 1s 5ms/step - loss: 0.3515 - accuracy: 0.8566
# Epoch 48/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3517 - accuracy: 0.8582
# Epoch 49/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3512 - accuracy: 0.8599
# Epoch 50/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3518 - accuracy: 0.8594
# 104/104 [==============================] - 0s 2ms/step
# array([[0.3699952 ],
#        [0.3817015 ],
#        [0.18214308],
#        ...,
#        [0.17261413],
#        [0.5293159 ],
#        [0.02458849]], dtype=float32)

# %%
y_pred=(y_pred>0.5) # t /f 1/0 0.5 den büyükse true
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)

cm
# Out:
# array([[2513,  104],
#        [ 373,  310]])
