# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/MachinaLearning/blob/main/APriori_algroritm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/ymoch/apyori/master/apyori.py
# Out:
# --2023-10-17 12:12:28--  https://raw.githubusercontent.com/ymoch/apyori/master/apyori.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14558 (14K) [text/plain]
# Saving to: ‘apyori.py’
#
# apyori.py           100%[===================>]  14.22K  --.-KB/s    in 0.001s
#
# 2023-10-17 12:12:28 (21.2 MB/s) - ‘apyori.py’ saved [14558/14558]

# %%
from apyori import apriori

# %%
# Pandas kütüphanesini içe aktar
import pandas as pd

# Excel dosyasını oku ve DataFrame'e dönüştür
data = pd.read_excel('/content/sepet.csv.xlsx')
data
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


rule=apriori(data,min_support=0.01,min_confidence=0.3,min_left=3,min_lenght=2)

list(rule)
